# %% [markdown]
# # Artificial Neural Networks

# %% [markdown]
# ## Q1
# If we have three layer-neural network with 512 neuron in each, how many parameters do we have to predict?

# %%
3*(512*512)
# Out:
# 786432

# %% [markdown]
# ## Q2
# For two given logical statements, the XOR function would return 1 if one of the statements is true and 0 if both statements are true. If neither of the statements is true, it also returns 0. We can show it as follows:
#
# 𝑥1:0101
#
# 𝑥2:0011
#
# 𝑥1 XOR 𝑥2:0110
#
# Do you think it is possible to perform this function using a single layer?

# %% [markdown]
# * Single layer will be enough

# %% [markdown]
# ## Q3
# Calculate the output value of the ANN below using the ReLU activation function.(y=?)

# %%
from PIL import Image
myImage = Image.open("C02_05.png");
myImage
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1241x489 at 0x7F85501829A0>

# %% [markdown]
# ReLu is very popular. It cuts off values below zero. So if the input is smaller than 0 it returns 0.
#
# y = 0 because one of the node in hidden 2 has negative value
#
# * Hidden1, Z1 = (4*2)+(3*3) = 17
# * Hidden1, Z2 = [(4*1)+(3*-6)= -14] = 0
# * Hidden2, Z1 = (17*1)+(0*3) = 17
# * Hidden2, Z2 = (17*2)+(0*3) = 34
#
# - y = [(17*-3)+(34*1) = -51] = 0
