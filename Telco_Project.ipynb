# %%
import pandas as pd
import numpy as np
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
print(round(df['Churn'].value_counts(normalize=True) * 100,2))
# Out:
# No     73.46
# Yes    26.54
# Name: Churn, dtype: float64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     6521-YYTYI   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# **Total charges variable appears object must be an float or integer!**

# %%
df['TotalCharges'].isna().sum()
# Out:
# 0

# %%
df['TotalCharges'].value_counts()
# Out:
#            11
# 20.2       11
# 19.75       9
# 19.9        8
# 20.05       8
#            ..
# 3043.6      1
# 4299.2      1
# 2169.8      1
# 1620.25     1
# 2043.45     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
df[df['TotalCharges'] == " "].index
# Out:
# Int64Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %%
df['Total_Charges'] = df['tenure']*df['MonthlyCharges']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# **Total_Charges column has created**

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  Total_Charges
# count    7043.000000  7043.000000     7043.000000    7043.000000
# mean        0.162147    32.371149       64.761692    2279.581350
# std         0.368612    24.559481       30.090047    2264.729447
# min         0.000000     0.000000       18.250000       0.000000
# 25%         0.000000     9.000000       35.500000     394.000000
# 50%         0.000000    29.000000       70.350000    1393.600000
# 75%         0.000000    55.000000       89.850000    3786.100000
# max         1.000000    72.000000      118.750000    8550.000000

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# Total_Charges       6051
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,12))

plt.subplot(2,2,1)
sns.countplot(x="Churn",hue="gender",data = df)
plt.title('Number of genders churned', c = "r")
plt.subplot(2,2,2)
sns.countplot(x="Churn",hue="SeniorCitizen",data=df)
plt.title('Number of senior citizen churned', c = "r")
plt.subplot(2,2,3)
sns.countplot(x="Churn",hue="Partner",data=df)
plt.title('Number of customer has a partner churned', c = "r")
plt.subplot(2,2,4)
sns.countplot(x="Churn",hue="Dependents",data=df)
plt.title('Number of customer has a dependent churned', c = "r")

plt.show()

# %%
df.drop(['gender', 'customerID'], axis = 1, inplace = True)

# %% [markdown]
# **Gender doesn't have a significant affect on Churn rate. Dropped!
# Citizens who are not Senior are more likely to Churn then seniors
# Also, customer id has dropped.**

# %%
def make_ordinal(Contract):
    if Contract == "Month-to-month":
        return "Pay as go"
    else: 
        return "Has plan"
    
df['HasContract'] = df["Contract"].apply(make_ordinal)

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
sns.boxplot(x = 'Churn',  y = 'MonthlyCharges',hue = 'Contract', data = df)
plt.title("Contract vs. Monthly Charges")

plt.subplot(1,2,2)
sns.boxplot(x = 'Churn',  y = 'Total_Charges',hue = 'HasContract', data = df)
plt.title("Internet Service vs. Total Charges")
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
sns.boxplot(x = 'Churn',  y = 'MonthlyCharges',hue = 'HasContract', data = df)
plt.title("Contract vs. Monthly Charges")
plt.subplot(1,2,2)
sns.boxplot(x = 'Churn',  y = 'Total_Charges',hue = 'HasContract', data = df)
plt.title("Contract vs. Total Charges")
plt.show()

# %%
import scipy.stats as stats
from scipy.stats.mstats import winsorize
import warnings
warnings.filterwarnings('ignore')

df["Winsorized_Total_Charges"] = winsorize(df['Total_Charges'], (0,0.15))

plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
sns.boxplot(x = 'Churn',  y = 'Winsorized_Total_Charges',hue = 'HasContract', data = df)
plt.title('Average Number of Winsorize Total Charges')

plt.subplot(1,2,2)
sns.barplot(df['Churn'],df["Winsorized_Total_Charges"])
plt.title('Average Number of Winsorize Total Charges')
plt.show()

# %% [markdown]
# **Average Total Charge for the customers not churned is 1.5 times higher than customers  churned**

# %%
stats.ttest_ind([df["Churn"]=="Yes"],df["Total_Charges"],axis=0,equal_var=True)
# Out:
# Ttest_indResult(statistic=array([nan, nan, nan, ..., nan, nan, nan]), pvalue=array([nan, nan, nan, ..., nan, nan, nan]))

# %%
plt.figure(figsize=(16,4))

sns.boxplot(x = 'Churn',  y = 'MonthlyCharges',hue = 'PaymentMethod', data = df)
plt.title("Payment Method vs. Monthly Charges")

plt.show()

# %% [markdown]
# **Customer whose choiced to pay by mailed check more tend to churn on high prices**

# %%
def make_ordinal(SeniorCitizen):
    if SeniorCitizen == 1:
        return "SeniorCitizen"
    else: 
        return "Not SeniorCitizen"
    
df['Senior_Citizen'] = df["SeniorCitizen"].apply(make_ordinal)

# %%
import math
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
df= pd.concat([df, pd.get_dummies(df["PaymentMethod"])], axis=1)
df= pd.concat([df, pd.get_dummies(df["InternetService"])], axis=1)
df= pd.concat([df, pd.get_dummies(df["HasContract"])], axis=1)
df= df.rename(columns={'No': 'NoInternet'})
df= pd.concat([df,pd.get_dummies(df["Senior_Citizen"],drop_first=True)],axis=1)
df= pd.concat([df,pd.get_dummies(df["Churn"],drop_first=True)],axis=1)
df= df.rename(columns={'Yes': 'Churn'})
df.head()
# Out:
#   SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 0             0     Yes         No       1           No  No phone service
# 1             0      No         No      34          Yes                No
# 2             0      No         No       2          Yes                No
# 3             0      No         No      45           No  No phone service
# 4             0      No         No       2          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection  ...  \
# 0             DSL             No          Yes               No  ...
# 1             DSL            Yes           No              Yes  ...
# 2             DSL            Yes          Yes               No  ...
# 3             DSL            Yes           No              Yes  ...
# 4     Fiber optic             No           No               No  ...
#
#   Credit card (automatic) Electronic check Mailed check DSL Fiber optic  \
# ...

# %%
df = df.iloc[:,22:35]
df_correlation = df.corr()
df_correlation
# Out:
#                            Bank transfer (automatic)  Credit card (automatic)  \
# Bank transfer (automatic)                   1.000000                -0.278215
# Credit card (automatic)                    -0.278215                 1.000000
# Electronic check                           -0.376762                -0.373322
# Mailed check                               -0.288685                -0.286049
# DSL                                         0.025476                 0.051438
# Fiber optic                                -0.022624                -0.050077
# NoInternet                                 -0.002113                 0.001030
# Has plan                                    0.179707                 0.204145
# Pay as go                                  -0.179707                -0.204145
# SeniorCitizen                              -0.016159                -0.024135
# Churn                                      -0.117937                -0.134302
#
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_correlation, annot=True, linewidths=.1, vmin=-1, vmax=1, cmap='viridis')
plt.title("Corrleation Matrix")
# Out:
# Text(0.5, 1.0, 'Corrleation Matrix')

# %%
df_n = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df_n.groupby('Churn').mean().T
# Out:
# Churn                  No        Yes
# SeniorCitizen    0.128721   0.254682
# tenure          37.569965  17.979133
# MonthlyCharges  61.265124  74.441332

# %%
df.groupby('Churn').mean().T
# Out:
# Churn                             0         1
# Bank transfer (automatic)  0.248550  0.138042
# Credit card (automatic)    0.249324  0.124131
# Electronic check           0.250097  0.573034
# Mailed check               0.252029  0.164794
# DSL                        0.379204  0.245586
# Fiber optic                0.347700  0.693954
# NoInternet                 0.273096  0.060460
# Has plan                   0.570932  0.114500
# Pay as go                  0.429068  0.885500
# SeniorCitizen              0.128721  0.254682

# %%
def make_ordinal(Contract):
    if Contract == "Month-to-month":
        return "Pay as go"
    else: 
        return "Has plan"
    
df_n['HasContract'] = df_n["Contract"].apply(make_ordinal)
ContractRating = pd.crosstab(df_n['Churn'],df_n['HasContract'])
ContractRating
# Out:
# HasContract  Has plan  Pay as go
# Churn
# No               2954       2220
# Yes               214       1655

# %%
sns.countplot(y='HasContract',hue='Churn',data = df_n)
plt.title('Plan type based on Churn')
plt.ylabel('Plan Type')
plt.show()

# %% [markdown]
# * H_0 = 0
# * H_A ≠ 0
# * A large t-score tells you that the groups are different.
# * A small t-score tells you that the groups are similar.

# %%
stats.ttest_ind(df_n['SeniorCitizen'][df_n['HasContract'] == 'Pay as go'],
                df_n['SeniorCitizen'][df_n['HasContract'] == 'Has plan'])
# Out:
# Ttest_indResult(statistic=11.722668181086911, pvalue=1.9093263442909655e-31)

# %% [markdown]
# **"p-value higher than 0.05 (> 0.05) is not statistically significant and indicates strong evidence for the null hypothesis."**
